# %%
import os
import json
import shlex
import subprocess
import uuid
from langchain.llms import OpenAI
from langchain.prompts import PromptTemplate
from openai import OpenAI as OpenAIClient

current_story_section = None
current_story_section_index = 0

def read_prompt_from_md(filename):
    """Read the content of a markdown file."""
    with open(filename, 'r') as file:
        return file.read().strip()

def temporary_save(content):
    """Save content to a temporary file."""
    temp_name = f"temp_{uuid.uuid4()}.txt"
    with open(temp_name, 'w') as file:
        file.write(content)

def trim_json_string(json_string):
    """Trim markdown formatting from a JSON string."""
    json_string = json_string.replace("```json", "").replace("```", "").strip()
    return json_string

def validate_json(pattern, json_string):
    """Validate and fix JSON string if necessary."""

    import glob 
    pattern_count = len(glob.glob(f"{pattern}_*.json"))
    pattern_count += 1
    json_string = trim_json_string(json_string)

    try:
        json_data = json.loads(json_string)
        with open(f"{pattern}_{pattern_count}.json", 'w') as file:
            json.dump(json_data, file, indent=2)
        return json_data
    except json.JSONDecodeError:
        print("Invalid JSON. Attempting to fix...")

        escaped_prompt = shlex.quote(json_string)
        cmd = ["/Users/jkatigbak/go/bin/fabric", "--pattern", "validate_json"]
        process = subprocess.Popen(cmd, stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)   
        stdout, stderr = process.communicate(input=json_string)
        result = subprocess.CompletedProcess(cmd, process.returncode, stdout, stderr)
        print(result.stdout)
        
        try: 
            json_string = trim_json_string(result.stdout)
            json_data = json.loads(json_string)
            with open(f"fixed_{pattern}_{pattern_count}.json", 'w') as file:
                json.dump(json_data, file, indent=2)
            return json_data
        except json.JSONDecodeError:
            print("Failed to fix JSON.")
            return None
        
def write_artifact(pattern, prompt, content):
    """Write the generated content to a file with an incremented index."""
    import glob
    files = glob.glob(f"{pattern}_*.txt")
    file_idx = len(files) + 1
    with open(f"{pattern}_{file_idx}.txt", "w") as file:
        file.write(prompt)
        file.write("\n\n===================\n\n")
        file.write(content)

def read_template(filename):
    """Read a JSON template from a file."""
    with open(filename, 'r') as file:
        return json.load(file)

def chat_completion(pattern, user_prompt):
    """Get a response from the chat model based on the user prompt."""
    try:
        # Escape special characters in user_prompt
        escaped_prompt = shlex.quote(user_prompt)
        
        # Use a list of arguments instead of shell=True for better security
        cmd = ["/Users/jkatigbak/go/bin/fabric", "--pattern", pattern]
        
        # Use subprocess.Popen to pipe the input
        process = subprocess.Popen(cmd, stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        
        # Send the user_prompt to stdin and get the output
        stdout, stderr = process.communicate(input=escaped_prompt)
        
        result = subprocess.CompletedProcess(cmd, process.returncode, stdout, stderr)
        write_artifact(pattern, user_prompt, result.stdout)
        return result.stdout
    except Exception as e:
        print(f"Error in chat completion: {e}")
        return None

def generate_story_outline(story_parameters):
    """Generate a story outline based on provided parameters."""
    user_prompt = f"These are the story parameters to fulfill your system prompt: {json.dumps(story_parameters)}, please output the outline requested."
    outline = chat_completion("story_outline", user_prompt)
    print(outline)
    return outline

def enhance_story_outline(initial_outline):
    user_prompt = f"Enhance this story outline by adding more details to each section into a valid JSON object: \n\n====\n\n{initial_outline}\n\n====\n\n Please ensure that the output is valid JSON."
    enhanced = chat_completion("story_outline_enhancement", user_prompt)
    print(enhanced)
    return validate_json("story_outline_enhancement", enhanced)

def develop_story_section(section_outline, story_outline):
    """Develop a specific section of the story based on the outline."""
    user_prompt = f"""This was the story outline that was used to create this section: \n\n{story_outline}\n\nSection Outline for you to develop: \n\n{json.dumps(section_outline)}\n\nPlease develop the section with the section provided, ensuring that the story remains cohesive and the plot points are well integrated."""   
    developed = chat_completion("story_development", user_prompt)
    print(developed)
    return developed

def pair_image_and_text(story_section):
    """Pair images with the corresponding text in the story section."""
    user_prompt = f"This is the story section to pair the image with: {json.dumps(story_section)}"
    paired = chat_completion("image_text_pairing", user_prompt)
    print(paired)
    return validate_json("image_text_pairing", paired)

def create_image_generation_prompt(image_description):
    """Create a prompt for image generation based on the description."""
    user_prompt = f"This is the image description object to create an image prompt for: {json.dumps(image_description)}, the output will be simple text without any formatting."
    prompt = chat_completion("image_generation", user_prompt)
    print(f"Image Prompt: {prompt}")
    return prompt

def get_api_key():
    """Retrieve the OpenAI API key from environment or file."""
    if api_key := os.environ.get('OPENAI_API_KEY'):
        return api_key
    with open('/Users/jkatigbak/.config/openai', 'r') as file:
        return file.read().strip()

def generate_image(prompt):
    """Generate an image based on the provided prompt."""
    try:
        api_key = get_api_key()
        print(api_key)
        os.environ['OPENAI_API_KEY'] = api_key
        # Generate the image
        client = OpenAIClient(api_key=api_key)
        response = client.images.generate(
            model="dall-e-3",
            prompt=prompt,
            size="1024x1024",
            quality="standard",
            n=1,
        )

        return response.data[0].url

    except Exception as e:
        print(f"Error generating image: {e}")
        return None

def output_results(full_story, storybook_content, image_prompts, image_urls):
    """Output the results to a JSON file."""
    with open('storybook_output.json', 'w') as f:
        json.dump({
            'full_story': full_story,
            'storybook_content': storybook_content,
            'image_prompts': image_prompts,
            'image_urls': image_urls
        }, f, indent=2)
    print("Results saved to storybook_output.json")

# %%
story_parameters = read_template('story_template.json')
initial_outline = generate_story_outline(story_parameters)
# Out:
# ```json
# {
#   "ageRange": "5-7 years",
#   "storyLength": "1000 words",
#   "themes": ["Imagination", "Creativity", "Friendship"],
#   "moralOfTheStory": "Using your imagination can turn the ordinary into something extraordinary.",
#   "characters": [
#     {
#       "name": "Luna",
#       "description": "A curious little girl with a vivid imagination"
#     },
#     {
#       "name": "Bubbles",
#       "description": "A friendly blue dragon who loves to fly"
#     },
#     {
#       "name": "Oliver",
#       "description": "A shy but clever boy who enjoys building things"
#     }
#   ],
#   "storySetting": "A whimsical village surrounded by enchanting hills and sparkling rivers",
#   "tone": "Playful and inspiring",
#   "parentalConcerns": [
#     "Ensure all characters are positive role models",
#     "Avoid any frightening elements"
#   ],
#   "inclusionAndDiversity": "Include characters from different backgrounds and cultures, showcasing diverse talents",
#   "ending": "Uplifting ending that inspires creativity and friendship",
#   "additionalInstructions": "Incorporate colorful illustrations to enhance the storytelling experience"
# }
# ```
#
# 1. **Introduction:**
#    - **Characters:** Introduce Luna, the imaginative little girl who loves to dream big; Bubbles, the friendly blue dragon who enjoys soaring through the skies; and Oliver, the shy but inventive boy who creates amazing things from everyday items.
#    - **Setting:** Describe the whimsical village filled with colorful houses, vibrant flowers, and winding paths leading to enchanting hills and sparkling rivers. The village is alive with laughter and creativity.
#    - **Initial Situation:** Luna often daydreams about adventures beyond the village, while Oliver spends his time crafting inventions but feels too shy to share them with others.
#
# 2. **Conflict/Problem:**
#    - One day, Luna discovers a mysterious map in her attic that leads to the “Land of Imagination,” a place where anything is possible. She wants to go on an adventure but needs a friend to join her. She finds Oliver and convinces him to come along, but Oliver is worried that his inventions won't be useful.
#
# 3. **Rising Action:**
#    - Luna and Oliver set off on their journey and soon encounter Bubbles, who is flying around playfully. They invite Bubbles to join them, and the three friends embark on their adventure together.
#    - Along the way, they face various imaginative challenges: they must cross a river of rainbow jelly, solve the riddle of the talking trees, and navigate through a maze made of giant candy canes.
#    - At each challenge, Luna uses her creativity to come up with wild ideas, while Oliver begins to gain confidence and contributes his inventions, like a jelly bridge and a candy cane compass.
#
# 4. **Climax:**
#    - The trio finally reaches the entrance to the Land of Imagination, guarded by a whimsical creature who will only let them in if they can create something extraordinary together. In a moment of doubt, Oliver hesitates, but Luna encourages him to trust in their friendship and creativity.
#    - They combine their ideas and work together to create a magnificent flying machine made of flowers, candy, and sparkles. The creature is impressed and allows them to enter.
#
# 5. **Falling Action:**
#    - Inside the Land of Imagination, Luna, Oliver, and Bubbles are greeted by colorful landscapes and creatures. They explore a world where they can fly, dance, and create anything they wish.
#    - As they play and explore, Oliver realizes that his inventions can bring joy and wonder to everyone, and he starts sharing his creations with the inhabitants of this magical land.
#
# 6. **Resolution:**
#    - After a day filled with fun, the friends decide to return to their village, bringing back the spirit of imagination with them. They promise to share their adventures and inspire others to dream big.
#    - The story concludes with Luna, Oliver, and Bubbles hosting a creativity festival in their village, where everyone can showcase their talents and inventions, celebrating friendship and imagination. The moral of the story shines through as the friends inspire others to use their imaginations to turn the ordinary into extraordinary adventures.
# ```

# %%
enhanced_outline = enhance_story_outline(initial_outline)
# Out:
# ```json
# {
#   "enhancedOutline": {
#     "Introduction": {
#       "plotPoints": [
#         "Luna is seen daydreaming under a big colorful tree, imagining herself as a brave explorer.",
#         "Bubbles, the friendly blue dragon, swoops down from the sky, playfully blowing bubbles that float around Luna.",
#         "Oliver is in his workshop, surrounded by quirky inventions like a toy robot and a kite made of colorful paper, feeling shy as he watches Luna and Bubbles from a distance.",
#         "The whimsical village is alive with colorful houses adorned with flowers, with children playing and laughing, showcasing the vibrant community."
#       ],
#       "characterDevelopment": {
#         "Luna": "Portrayed as adventurous and imaginative, always dreaming of new possibilities.",
#         "Bubbles": "Demonstrates a playful spirit and a love for friendship, eager to join Luna's adventures.",
#         "Oliver": "Introduced as shy but clever, with a passion for building, hinting at his potential to grow throughout the story."
#       },
#       "themeIntegration": "The theme of imagination is introduced as Luna dreams of adventures, setting the stage for the extraordinary journey ahead.",
#       "illustrationIdea": "A vibrant scene of Luna under the tree, with colorful bubbles floating around her and Oliver tinkering in his workshop."
#     },
#     "Conflict": {
#       "plotPoints": [
#         "While exploring her attic, Luna finds an old, dusty map that shows the way to the 'Land of Imagination' with bright illustrations.",
#         "Excited, Luna rushes to Oliver's workshop, where he is building a new invention, to share her discovery.",
#         "Oliver expresses his concerns about not being brave enough or having useful inventions for the adventure.",
#         "Luna reassures Oliver, emphasizing the importance of friendship and creativity in overcoming challenges."
#       ],
#       "characterDevelopment": {
#         "Luna": "Shows determination and optimism, eager to embark on an adventure despite the unknown.",
#         "Oliver": "Struggles with self-doubt, highlighting his growth potential as he learns to trust his abilities."
#       },
#       "themeIntegration": "The conflict reflects the importance of friendship and the courage to explore the unknown, encouraging readers to believe in their capabilities.",
#       "illustrationIdea": "A whimsical illustration of Luna excitedly showing Oliver the map, with Oliver looking hesitant yet intrigued."
#     },
#     "RisingAction": {
#       "plotPoints": [
#         "Luna and Oliver set out on their adventure, walking along a sparkling river, where they stumble upon Bubbles flying in circles.",
#         "They invite Bubbles to join them, and the trio forms a strong bond as they share their dreams of adventure.",
#         "The first challenge appears as they approach a river of rainbow jelly, where they must figure out how to cross without getting stuck.",
#         "Luna comes up with the idea to create stepping stones out of jelly, while Oliver invents a jelly bridge that helps them cross safely."
#       ],
#       "characterDevelopment": {
#         "Luna": "Continues to lead with creativity and encourages her friends to think outside the box.",
#         "Oliver": "Begins to find confidence in his inventions, realizing that they can be useful and fun."
#       },
#       "themeIntegration": "Imagination and creativity shine as the friends work together to solve problems, reinforcing the idea that teamwork enhances creativity.",
#       "illustrationIdea": "The trio crossing the colorful river on a jelly bridge, with Bubbles flying above and Luna and Oliver laughing."
#     },
#     "Climax": {
#       "plotPoints": [
#         "The trio finally arrives at the entrance to the Land of Imagination, which is guarded by a whimsical creature with sparkling eyes.",
#         "The creature challenges them to create something extraordinary, causing Oliver to doubt his abilities once again.",
#         "Luna encourages Oliver to share his ideas, reminding him of the power of friendship and teamwork.",
#         "Together, they design a magnificent flying machine made of flowers, candy, and sparkles, showcasing their unique talents."
#       ],
#       "characterDevelopment": {
#         "Luna": "Demonstrates leadership and support, helping Oliver realize the value of their friendship.",
#         "Oliver": "Overcomes his self-doubt, contributing his inventive skills to create something magical."
#       },
#       "themeIntegration": "The climax highlights the importance of collaboration and the magic that happens when friends combine their imaginations.",
#       "illustrationIdea": "A colorful scene of the whimsical creature observing the trio as they proudly unveil their flying machine."
#     },
#     "FallingAction": {
#       "plotPoints": [
#         "Once inside the Land of Imagination, they are greeted by vibrant landscapes filled with colorful flowers and playful creatures.",
#         "They explore various areas, including a garden where trees dance and a pond where the water sings.",
#         "Oliver gains confidence as he shares his inventions with the magical creatures, who are thrilled by his creativity.",
#         "The trio creates a joyful celebration in the land, showcasing their talents and inspiring others to join in the fun."
#       ],
#       "characterDevelopment": {
#         "Luna": "Continues to embrace her adventurous spirit, enjoying the magic of imagination.",
#         "Oliver": "Blooms into a more confident version of himself, realizing his inventions can bring joy to others."
#       },
#       "themeIntegration": "The theme of friendship and creativity flourishes as they share their ideas and inventions, illustrating the joy of collaboration.",
#       "illustrationIdea": "A lively scene of Luna, Oliver, and Bubbles celebrating with colorful creatures in the enchanting landscape."
#     },
#     "Resolution": {
#       "plotPoints": [
#         "After a day filled with adventure, the friends decide it's time to return to their village, bringing the spirit of imagination with them.",
#         "They plan a creativity festival to share their experiences and inspire others in their village to dream big.",
#         "The festival features colorful booths where villagers can showcase their talents, inventions, and creativity.",
#         "The story concludes with Luna, Oliver, and Bubbles watching the sunset, their hearts full of joy and inspiration."
#       ],
#       "characterDevelopment": {
#         "Luna": "Embraces her role as a leader and inspiration for others, ready to share her adventures.",
#         "Oliver": "Transforms into a more confident and outgoing boy, eager to share his inventions and creativity."
#       },
#       "themeIntegration": "The resolution reinforces the moral that using imagination can turn ordinary moments into extraordinary experiences, encouraging readers to explore their creativity.",
#       "illustrationIdea": "A vibrant festival scene with Luna, Oliver, and Bubbles at the center, surrounded by happy villagers showcasing their talents."
#     }
#   }
# }
# ```

# %%
def process_story_section(section_name, enhanced_outline, initial_outline):
    story_section = develop_story_section({section_name: enhanced_outline['enhancedOutline'][section_name]}, initial_outline)
    
    paired_image_and_text = pair_image_and_text(story_section)
    
    image_prompt = create_image_generation_prompt(paired_image_and_text['imageDescription'])
    
    image = generate_image(image_prompt)
    
    return {
        'story_section': story_section,
        'pair_image_and_text': paired_image_and_text,
        'image_prompt': image_prompt,
        'image': image
    }


# Process Introduction section
introduction_result = process_story_section('Introduction', enhanced_outline, initial_outline)

# introduction_story_section = develop_story_section({'Introduction': enhanced_outline['enhancedOutline']['Introduction']}, initial_outline)
# paired_image_and_text = pair_image_and_text(introduction_story_section)
# Out:
# ### Introduction
#
# In a whimsical village filled with colorful houses and vibrant flowers, there was a big, colorful tree that stood proudly in the center of a sunlit meadow. Underneath its wide branches, a curious little girl named Luna sat daydreaming. With her bright eyes sparkling with excitement, she imagined herself as a brave explorer, sailing across oceans of candy and climbing mountains made of marshmallows.
#
# As she closed her eyes, her imagination painted vivid pictures of daring adventures. "I could discover magical lands and meet friendly creatures!" she whispered to herself, a smile dancing on her lips. Just then, a swoosh of air rustled the leaves above her, and a friendly blue dragon named Bubbles swooped down from the sky. Bubbles was not just any dragon; he loved to play, and today was no different.
#
# “Look out below!” he called out with a cheerful roar, blowing bubbles that floated gracefully around Luna like tiny rainbows. Each bubble shimmered in the sunlight, reflecting all the colors of the village. Luna giggled, reaching out to pop one with her finger. “Bubbles! You always know how to brighten my day!”
#
# Meanwhile, just a short distance away, in his cozy workshop filled with quirky inventions, sat Oliver. Surrounded by gadgets and gizmos—like a toy robot that danced and a colorful kite made of paper—he watched Luna and Bubbles from a distance. Oliver was a shy boy, clever and inventive, but he often felt too timid to join in the fun. “I wish I could be as brave as Luna,” he murmured to himself, fiddling with a small gadget in his hands.
#
# The village was alive with laughter and creativity, as children played together, running along winding paths and sharing stories of their own imaginative games. The air was filled with the sweet scent of blooming flowers, and the sound of cheerful chatter echoed throughout the vibrant community.
#
# Luna, with her adventurous spirit, and Bubbles, with his playful heart, represented the boundless possibilities of imagination. As they floated around in a world where dreams could come true, Oliver remained in his workshop, hinting at the potential for growth that lay within him.
#
# With the promise of adventure swirling in the air, Luna’s dreams were about to take flight, and little did they know that this was just the beginning of a journey that would change everything. The theme of imagination glimmered in the sunlight, setting the stage for the extraordinary adventure that awaited them all.
#
# ---
#
# *Illustration Idea: A vibrant scene depicting Luna joyfully seated beneath the colorful tree, surrounded by floating bubbles created by Bubbles. In the background, Oliver is seen peeking out from his workshop, filled with quirky inventions, while the whimsical village buzzes with life, showcasing children playing and the beauty of their surroundings.*
#
# ```json
# {
#   "pageNumber": 6,
#   "imageDescription": {
#     "style": "Whimsical watercolor and ink illustration with a blend of rich earth tones and vibrant greens, maintaining the playful and energetic feel characteristic of Quentin Blake.",
#     "scene": "Inside the Dark Forest, where towering trees surround Lily, their thick trunks covered in moss. Faint beams of light filter through the leaves, casting a magical glow on the forest floor, which is dotted with colorful mushrooms and soft ferns.",
#     "characters": [
#       {
#         "name": "Lily",
#         "description": "Lily is now deeper in the forest, her expression shifting from apprehension to wonder. Her curly red hair bounces with each step, and her blue dress contrasts beautifully against the greens and browns of the forest. The amulet in her hand glows brighter, illuminating her face."
#       }
#     ],
#     "action": "Lily is walking further into the forest, her eyes wide with amazement as she discovers the beauty hidden within the shadows.",
#     "perspective": "Medium shot, focusing on Lily as she walks, with the trees forming a natural frame around her. This angle captures both her smallness in the vast forest and the magical details of her surroundings.",
#     "lighting": "Soft, diffused light from above creates a mystical atmosphere, with the amulet casting a warm glow that highlights Lily's features and the delicate textures of the forest floor.",
#     "textPlacement": "Lower right corner, allowing the viewer to focus on Lily's expression and the enchanting environment without obstruction."
#   },
#   "text": "As Lily ventured deeper into the Dark Forest, she marveled at the beauty around her. Glowing mushrooms peeked from under the leaves, and the trees whispered secrets of old. 'This place is magical!' she exclaimed, feeling her courage grow with every step."
# }
# ```
#
# Image Prompt: ```json
# {
#   "pageNumber": 5,
#   "imageDescription": {
#     "style": "Whimsical watercolor and ink illustration with a palette of deep greens, purples, and a contrasting bright blue for Lily's dress. Loose, energetic line work in a playful, sketchy style.",
#     "scene": "The edge of the Dark Forest. Towering trees with twisted branches form a looming, mysterious entrance. The forest floor is covered in gnarled roots and patches of mist.",
#     "characters": [
#       {
#         "name": "Lily",
#         "description": "A small figure with wild, curly red hair and a bright blue dress. Her face shows a mix of determination and apprehension. She's clutching a glowing amulet that casts a soft light around her."
#       }
#     ],
#     "action": "Lily is taking her first step into the Dark Forest, one foot forward, her body leaning slightly as if pushing against an invisible barrier.",
#     "perspective": "Wide shot, viewing Lily from a slight angle to show both her face and the expanse of the forest before her. The trees loom large, dwarfing Lily to emphasize the challenge ahead.",
#     "lighting": "Contrast between the darker, shadowy forest and the soft glow emanating from Lily's amulet. Dappled light breaks through the canopy in places, creating spots of illumination in the gloom."
#   },
#   "text": "Lily stood at the edge of the Dark Forest, her heart pounding. The trees seemed to whisper warnings, but she thought of her friend and squeezed her magic amulet tight. 'I can do this,' she said softly, and took her first brave step into the shadows.",
#   "storyInfo": {
#     "theme": "Courage and friendship",
#     "tone": "Adventurous with a touch of whimsy",
#     "ageRange": "6-8 years"
#   },
#   "styleReference": "Whimsical, sketchy style with loose, energetic line work"
# }
# ```
#
# Whimsical watercolor and ink illustration with playful, sketchy style. Soft, dreamy colors featuring deep greens and purples, contrasted by a bright blue dress. Scene set at the edge of a mysterious Dark Forest, with towering, twisted trees creating a looming entrance. Misty forest floor littered with gnarled roots. A small girl, Lily, with wild, curly red hair in a bright blue dress stands at the forest's edge, taking a brave first step forward. Her expression reflects determination mixed with apprehension as she clutches a glowing amulet that casts a soft light. Wide-angle view highlights the towering trees, dwarfing Lily. The contrast between the shadowy forest and the amulet's glow, with dappled light filtering through the canopy. Maintain loose, energetic line work for a sense of adventure and courage, suitable for 6-8 year olds, avoiding overly frightening elements.
#
# sk-svcacct-vVsUwDLhfnZ6VU76QJ14OGrPnB515fgmZTgLLcWMpXPWKT3BlbkFJqmsAc1P4jLSi5ZCWIvVkmUzZ48fCwntnXcqLV3eMdR5AA

# %%
introduction_result
# Out:
# {'story_section': '### Introduction\n\nIn a whimsical village filled with colorful houses and vibrant flowers, there was a big, colorful tree that stood proudly in the center of a sunlit meadow. Underneath its wide branches, a curious little girl named Luna sat daydreaming. With her bright eyes sparkling with excitement, she imagined herself as a brave explorer, sailing across oceans of candy and climbing mountains made of marshmallows. \n\nAs she closed her eyes, her imagination painted vivid pictures of daring adventures. "I could discover magical lands and meet friendly creatures!" she whispered to herself, a smile dancing on her lips. Just then, a swoosh of air rustled the leaves above her, and a friendly blue dragon named Bubbles swooped down from the sky. Bubbles was not just any dragon; he loved to play, and today was no different. \n\n“Look out below!” he called out with a cheerful roar, blowing bubbles that floated gracefully around Luna like tiny rainbows. Each bubble shimmered in the sunlight, reflecting all the colors of the village. Luna giggled, reaching out to pop one with her finger. “Bubbles! You always know how to brighten my day!” \n\nMeanwhile, just a short distance away, in his cozy workshop filled with quirky inventions, sat Oliver. Surrounded by gadgets and gizmos—like a toy robot that danced and a colorful kite made of paper—he watched Luna and Bubbles from a distance. Oliver was a shy boy, clever and inventive, but he often felt too timid to join in the fun. “I wish I could be as brave as Luna,” he murmured to himself, fiddling with a small gadget in his hands. \n\nThe village was alive with laughter and creativity, as children played together, running along winding paths and sharing stories of their own imaginative games. The air was filled with the sweet scent of blooming flowers, and the sound of cheerful chatter echoed throughout the vibrant community. \n\nLuna, with her adventurous spirit, and Bubbles, with his playful heart, represented the boundless possibilities of imagination. As they floated around in a world where dreams could come true, Oliver remained in his workshop, hinting at the potential for growth that lay within him. \n\nWith the promise of adventure swirling in the air, Luna’s dreams were about to take flight, and little did they know that this was just the beginning of a journey that would change everything. The theme of imagination glimmered in the sunlight, setting the stage for the extraordinary adventure that awaited them all. \n\n---\n\n*Illustration Idea: A vibrant scene depicting Luna joyfully seated beneath the colorful tree, surrounded by floating bubbles created by Bubbles. In the background, Oliver is seen peeking out from his workshop, filled with quirky inventions, while the whimsical village buzzes with life, showcasing children playing and the beauty of their surroundings.*\n',
#  'pair_image_and_text': {'pageNumber': 6,
#   'imageDescription': {'style': 'Whimsical watercolor and ink illustration with a blend of rich earth tones and vibrant greens, maintaining the playful and energetic feel characteristic of Quentin Blake.',
#    'scene': 'Inside the Dark Forest, where towering trees surround Lily, their thick trunks covered in moss. Faint beams of light filter through the leaves, casting a magical glow on the forest floor, which is dotted with colorful mushrooms and soft ferns.',
#    'characters': [{'name': 'Lily',
#      'description': 'Lily is now deeper in the forest, her expression shifting from apprehension to wonder. Her curly red hair bounces with each step, and her blue dress contrasts beautifully against the greens and browns of the forest. The amulet in her hand glows brighter, illuminating her face.'}],
#    'action': 'Lily is walking further into the forest, her eyes wide with amazement as she discovers the beauty hidden within the shadows.',
#    'perspective': 'Medium shot, focusing on Lily as she walks, with the trees forming a natural frame around her. This angle captures both her smallness in the vast forest and the magical details of her surroundings.',
#    'lighting': "Soft, diffused light from above creates a mystical atmosphere, with the amulet casting a warm glow that highlights Lily's features and the delicate textures of the forest floor.",
#    'textPlacement': "Lower right corner, allowing the viewer to focus on Lily's expression and the enchanting environment without obstruction."},
#   'text': "As Lily ventured deeper into the Dark Forest, she marveled at the beauty around her. Glowing mushrooms peeked from under the leaves, and the trees whispered secrets of old. 'This place is magical!' she exclaimed, feeling her courage grow with every step."},
#  'image_prompt': '```json\n{\n  "pageNumber": 5,\n  "imageDescription": {\n    "style": "Whimsical watercolor and ink illustration with a palette of deep greens, purples, and a contrasting bright blue for Lily\'s dress. Loose, energetic line work in a playful, sketchy style.",\n    "scene": "The edge of the Dark Forest. Towering trees with twisted branches form a looming, mysterious entrance. The forest floor is covered in gnarled roots and patches of mist.",\n    "characters": [\n      {\n        "name": "Lily",\n        "description": "A small figure with wild, curly red hair and a bright blue dress. Her face shows a mix of determination and apprehension. She\'s clutching a glowing amulet that casts a soft light around her."\n      }\n    ],\n    "action": "Lily is taking her first step into the Dark Forest, one foot forward, her body leaning slightly as if pushing against an invisible barrier.",\n    "perspective": "Wide shot, viewing Lily from a slight angle to show both her face and the expanse of the forest before her. The trees loom large, dwarfing Lily to emphasize the challenge ahead.",\n    "lighting": "Contrast between the darker, shadowy forest and the soft glow emanating from Lily\'s amulet. Dappled light breaks through the canopy in places, creating spots of illumination in the gloom."\n  },\n  "text": "Lily stood at the edge of the Dark Forest, her heart pounding. The trees seemed to whisper warnings, but she thought of her friend and squeezed her magic amulet tight. \'I can do this,\' she said softly, and took her first brave step into the shadows.",\n  "storyInfo": {\n    "theme": "Courage and friendship",\n    "tone": "Adventurous with a touch of whimsy",\n    "ageRange": "6-8 years"\n  },\n  "styleReference": "Whimsical, sketchy style with loose, energetic line work"\n}\n```\n\nWhimsical watercolor and ink illustration with playful, sketchy style. Soft, dreamy colors featuring deep greens and purples, contrasted by a bright blue dress. Scene set at the edge of a mysterious Dark Forest, with towering, twisted trees creating a looming entrance. Misty forest floor littered with gnarled roots. A small girl, Lily, with wild, curly red hair in a bright blue dress stands at the forest\'s edge, taking a brave first step forward. Her expression reflects determination mixed with apprehension as she clutches a glowing amulet that casts a soft light. Wide-angle view highlights the towering trees, dwarfing Lily. The contrast between the shadowy forest and the amulet\'s glow, with dappled light filtering through the canopy. Maintain loose, energetic line work for a sense of adventure and courage, suitable for 6-8 year olds, avoiding overly frightening elements.\n',
#  'image': 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-seARmrbVXHeX6K3QMfIjLhdw/test/img-fA0OgInM1Vs2kqU0ESgykqGv.png?st=2024-09-04T05%3A20%3A51Z&se=2024-09-04T07%3A20%3A51Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-09-04T01%3A45%3A39Z&ske=2024-09-05T01%3A45%3A39Z&sks=b&skv=2024-08-04&sig=6KmLV9znzv0MtGqCyEQIT0OBNsJMvgZsw4IaFc5jGqo%3D'}

# %%
# Out:
# 'In the heart of a vibrant meadow, where daisies danced in the gentle breeze and sunflowers stood tall like cheerful sentinels, there lived a shy little rabbit named Luna. She loved to daydream, her imagination a tapestry of adventures and friendships. But on this sunny day, as she peeked out from behind a blooming flower, her heart fluttered with uncertainty. \n\nLuna watched her friends play tag, their laughter ringing like sweet chimes in the air. Benny, the energetic bear, rolled down a grassy hill, his joyful giggles echoing as he tumbled to a stop, his fur glistening in the sun. “Whee! Come on, everyone!” he called out, inviting all the animals to join in the fun. Nearby, Tilly, the wise turtle, shared stories of brave explorers with a group of younger animals, her voice warm and soothing. “And they crossed rivers and climbed mountains, all with courage in their hearts!” she narrated, her eyes sparkling like the river that flowed gently nearby.\n\nAs Luna watched, her heart ached with longing. She imagined herself leaping into the game, her tiny feet bounding through the grass as she chased after her friends. But each time she thought about joining, her timid nature held her back like a heavy stone. What if they didn’t want her to play? What if she got lost? The worries tangled in her mind, making her feel smaller than ever.\n\nThe meadow was alive with colors and sounds—buzzing bees flitting from flower to flower, butterflies fluttering gracefully, and the soft gurgle of the sparkling river adding a peaceful rhythm to the day. Luna took a deep breath, the sweet scent of wildflowers filling her nose. She gathered her courage, her little heart beating like a drum. “Maybe… just maybe, I can join them,” she whispered to herself, her voice barely louder than the rustling leaves.\n\nWith a determined twitch of her nose, Luna stepped forward, ready to take that first leap into adventure. The sunlight warmed her fur, and for a moment, she felt the thrill of possibility. “I can do this!” she thought, imagining the joy of laughter and friendship. But still, the little rabbit hesitated, peeking out from behind her flower, her heart racing at the thought of what lay ahead.\n\nIn that moment, Luna realized that sometimes, it takes a little bravery to embrace the wonderful things waiting just outside her comfort zone. With Benny and Tilly nearby, perhaps this day could become the beginning of something magical. As she watched her friends, Luna felt a spark of hope, the kind that whispers, “Believe in yourself, and you can achieve great things.” \n\nAnd so, in the vibrant meadow filled with laughter and light, Luna prepared to take her first brave steps towards friendship and adventure.\n'

# %%
problem_result = process_story_section('Conflict', enhanced_outline, initial_outline)
# Out:
# ### Conflict/Problem
#
# On a sunny day in the vibrant meadow, Benny the cheerful bear stood atop a large, sun-warmed rock, his eyes sparkling with excitement. "Friends, gather around!" he called, waving his paws in the air. Luna, the shy little rabbit, sat under a blossoming cherry tree, her heart fluttering like the butterflies dancing nearby. She watched her friends—Benny and Tilly—wondering what grand adventure Benny was planning this time.
#
# Benny's voice rang out again, "I have the most exciting idea! Let’s explore the magical Whispering Woods! It’s a land filled with wonders, sparkles, and sounds that twinkle like stars!" His eyes shone with anticipation as he painted a picture of the enchanted forest.
#
# As Benny spoke, Luna’s heart raced. She imagined the tall trees whispering secrets, the shimmering lights of fireflies, and the unknown creatures lurking behind every bush. "What if I get lost?" she thought, her little ears drooping slightly. "What if I hear strange sounds and can't find my way back?"
#
# Tilly, the wise turtle, noticed Luna's worried expression. "Luna," she said gently, "I remember my first adventure. I felt scared too! But bravery isn’t about not feeling afraid; it’s about being courageous enough to face those fears." She smiled warmly, her eyes crinkling like soft leaves in the breeze.
#
# Luna took a deep breath, her heart still fluttering. She wanted to be brave like Benny and Tilly, to feel the thrill of adventure. But the thought of wandering into the unknown made her tummy twist with worry. "But what if I get lost in the woods?" she asked quietly, her voice barely above a whisper. "And what if those strange sounds are from creatures I can't see?"
#
# Benny, sensing her hesitation, hopped down from the rock and padded over to her side. "Luna, we will stick together! I promise. Friendship can light the way through any darkness. If we’re all together, there’s nothing to be afraid of!" His warm, reassuring smile made Luna's heart feel a little lighter, like a gentle breeze through the meadow.
#
# As Tilly nodded encouragingly, Luna looked from Benny to Tilly and back again. She could feel the warmth of their friendship wrapping around her like a cozy blanket. Maybe, just maybe, she could find the courage to join them.
#
# In that moment, Luna realized that even though her fears felt big, her friends were even bigger. The woods might be filled with wonders, and maybe, just maybe, she could be brave enough to explore them with Benny and Tilly by her side.
#
# As the sun shone brightly overhead, painting the meadow in hues of gold, Luna took a small step forward, her heart still racing, but filled with a flicker of hope. Would she take that leap into adventure? Only time would tell.
#
# ---
#
# This section captures the conflict where Luna grapples with her fears while being encouraged by her friends. It integrates the theme of facing fears and the importance of friendship, laying the groundwork for Luna's internal struggle and growth. The dialogue and actions of the characters maintain their established traits, ensuring a seamless flow into the rising action of the story.

# %%
rising_action_story_section = develop_story_section({'RisingAction': enhanced_outline['enhancedOutline']['RisingAction']}, initial_outline)
# Out:
# As Luna, Benny, and Tilly stepped into the Whispering Woods, the world around them transformed in the most magical way. The trees, tall and ancient, seemed to lean in closer, their leaves rustling softly like they were sharing secrets just for the trio. Sunlight danced through the branches, creating playful patterns on the forest floor, and a gentle breeze whispered sweet melodies that made the air feel alive. Luna took a deep breath, her heart fluttering with a mix of excitement and nervousness.
#
# “Look at the colors!” Benny exclaimed, his eyes sparkling with wonder as he pointed at the vibrant flowers peeking through the underbrush. “This place is amazing!”
#
# But just as they ventured deeper, they came upon their first challenge: a bubbling stream with slippery stepping stones scattered across the water. The stones glistened like little jewels, but Luna’s tummy twisted into knots at the thought of crossing.
#
# “I can’t do it,” she murmured, taking a small step back.
#
# Benny turned to her, his face full of encouragement. “You can, Luna! Just remember, you’re stronger than you think! I’ll be right here with you.” He took a confident leap onto the first stone, splashing water in a joyful arc.
#
# With a gentle nudge from Tilly, who was watching from the grass, Luna felt a spark of courage. “You can do this!” Tilly’s wise voice floated to her, reminding her of all the times she’d tried new things.
#
# Taking a deep breath, Luna stepped forward, her foot landing on the first stone. It wobbled slightly, but she steadied herself, feeling Benny’s supportive cheer behind her. “That’s it! Just one step at a time!” he called out. Encouraged, she leapt to the next stone, her heart racing but a smile breaking across her face.
#
# As they crossed the stream, the tall grass ahead tickled their noses, and Luna couldn’t help but giggle. The laughter bubbled up inside her, washing away her fears like the gentle current below. “This is fun!” she exclaimed, her spirit lifting with each step.
#
# Next, they found themselves at the entrance of a maze of trees, their trunks twisting and turning in every direction. Luna’s heart thumped as she looked around, feeling a bit lost. But then she remembered Tilly’s words: “Stay calm, Luna. Just follow the sun’s rays.” She took a deep breath and focused on the warm light filtering through the branches.
#
# “Let’s go this way!” Luna pointed confidently towards a patch of sunlight breaking through the leaves. Benny and Tilly nodded, and together they navigated through the maze, Luna leading the way. With each turn, she felt a sense of pride blossom inside her; she was guiding her friends!
#
# “Luna, you’re doing it!” Benny cheered, his enthusiasm echoing through the woods. Tilly smiled, her eyes twinkling with pride. “You’re learning to trust yourself, dear Luna. That’s wonderful!”
#
# With every small victory, Luna’s confidence grew. She laughed and smiled, feeling the warmth of friendship surrounding her like a cozy blanket. The worries that once felt so heavy began to lift, replaced by the joy of adventure and the strength of her friends beside her.
#
# As they finally stepped out of the maze and into a sunny clearing, Luna felt a rush of happiness swell in her chest. They were ready for whatever lay ahead—together.

# %%
climax_story_section = develop_story_section({'Climax': enhanced_outline['enhancedOutline']['Climax']}, initial_outline)
# Out:
# ### Climax
#
# The sun shone brightly as Luna, Benny, and Tilly stepped into a beautiful clearing filled with wildflowers dancing in the gentle breeze. The vibrant colors of the flowers—reds, yellows, and purples—painted the meadow like a joyful rainbow. In the center of this magical place, something sparkled under the sun. It was a treasure chest, glimmering with golden light, and Luna's heart raced with excitement.
#
# But as they approached, they noticed a little fox peeking out from behind a bush. Its bright orange fur shimmered in the sunlight, but its wide eyes were filled with uncertainty. The fox trembled, unsure of what to make of the visitors. “Who are they? What do they want?” it seemed to think, retreating further into the shadows.
#
# Luna’s heart sank. She remembered how scared she felt when Benny first invited her on this adventure. “What if the fox is just like me?” she whispered to herself, feeling a mix of fear and empathy. She glanced at Benny, who was already taking a step toward the fox, his cheerful demeanor shining bright.
#
# “Hey there, little friend! We just want to—” Benny began, but the fox darted back, its bushy tail disappearing behind the leaves. Luna could see the fear in its eyes. “Wait, Benny! Let me try,” she said, surprising even herself with her own courage.
#
# Taking a deep breath, Luna stepped forward, her heart pounding in her chest. She knelt down, making herself small and approachable. “Hello, Mr. Fox,” she said softly, her voice gentle like a lullaby. “I’m Luna, and these are my friends, Benny and Tilly. We’ve come to explore, just like you might want to. I know it can be scary to meet new friends.”
#
# The fox peeked out cautiously, its ears twitching. “You… you want to be friends?” it whispered, trembling.
#
# “Yes!” Luna replied, her eyes sparkling with sincerity. “I was once scared like you. But with Benny and Tilly by my side, I learned that it’s okay to be afraid sometimes. They helped me find my bravery, and I believe you can be brave too.”
#
# Tilly nodded, her wise eyes gleaming. “Kindness can help us all feel safe, dear fox. You don’t have to be alone.”
#
# The fox hesitated, contemplating Luna's words. Slowly, it took a step forward, its curiosity piqued. “You really mean it?” it asked, its voice still trembling but with a hint of hope.
#
# “Yes!” Benny chimed in, his excitement bubbling over. “Together, we can find treasure and adventure! We promise to stick together!”
#
# Luna smiled warmly, feeling a connection forming. “You’re not alone anymore. We can explore together, if you’d like.”
#
# The fox’s expression softened, and it stepped out from behind the bush, revealing its full self. “Okay… I’d like that,” it said shyly, a small smile breaking through its fear.
#
# With the fox now among them, they all approached the treasure chest together. Luna felt a rush of joy and pride. She had faced her fears not only for herself but to help someone else. In that moment, she realized that understanding and compassion could truly overcome fear.
#
# As they gathered around the chest, a new adventure awaited them, and Luna knew that with friends by her side, they could achieve great things. Together, they opened the treasure chest, revealing beautiful trinkets that sparkled like stars, and a map that promised even more wonders to explore. The clearing, once filled with uncertainty, now buzzed with laughter and excitement, marking the beginning of a beautiful friendship.

# %%
falling_action_story_section = develop_story_section({'FallingAction': enhanced_outline['enhancedOutline']['FallingAction']}, initial_outline)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[236], line 1
# ----> 1 falling_action_story_section = develop_story_section({'FallingAction': enhanced_outline['enhancedOutline']['FallingAction']}, initial_outline)
#
# Cell In[228], line 95, in develop_story_section(section_outline, story_outline)
#      93 """Develop a specific section of the story based on the outline."""
#      94 user_prompt = f"""This was the story outline that was used to create this section: \n\n{story_outline}\n\nSection Outline for you to develop: \n\n{json.dumps(section_outline)}\n\nPlease develop the section with the section provided, ensuring that the story remains cohesive and the plot points are well integrated."""
# ---> 95 developed = chat_completion("story_development", user_prompt)
#      96 print(developed)
#      97 return developed
#
# Cell In[228], line 70, in chat_completion(pattern, user_prompt)
#      67 process = subprocess.Popen(cmd, stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
#      69 # Send the user_prompt to stdin and get the output
# ---> 70 stdout, stderr = process.communicate(input=escaped_prompt)
#      72 result = subprocess.CompletedProcess(cmd, process.returncode, stdout, stderr)
#      73 write_artifact(pattern, user_prompt, result.stdout)
#
# File ~/miniconda3/lib/python3.12/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File ~/miniconda3/lib/python3.12/subprocess.py:2113, in Popen._communicate(self, input, endtime, orig_timeout)
#    2106     self._check_timeout(endtime, orig_timeout,
#    2107                         stdout, stderr,
#    2108                         skip_check_and_raise=True)
#    2109     raise RuntimeError(  # Impossible :)
#    2110         '_check_timeout(..., skip_check_and_raise=True) '
#    2111         'failed to raise TimeoutExpired.')
# -> 2113 ready = selector.select(timeout)
#    2114 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2116 # XXX Rewrite these to use non-blocking I/O on the file
#    2117 # objects; they are no longer using C stdio!
#
# File ~/miniconda3/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
resolution_story_section = develop_story_section({'Resolution': enhanced_outline['enhancedOutline']['Resolution']}, initial_outline)

# %%
full_story = story_development(enhanced_outline)
# Out:
# /var/folders/8z/rx0dw8cj6d35_d3s4m5ffwlc0000gn/T/ipykernel_55716/3844839285.py:1: RuntimeWarning: coroutine 'story_development' was never awaited
#   full_story = story_development(enhanced_outline)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
def main():
    # Read input from template file
    story_parameters = read_template('story_template.json')

    # Generate initial story outline
    initial_outline = generate_story_outline(story_parameters)
    if not initial_outline:
        print("Failed to generate valid story outline.")
        return

    # Enhance story outline
    enhanced_outline = enhance_story_outline(initial_outline)
    if not enhanced_outline:
        print("Failed to enhance story outline.")
        return

    # Develop full story
    full_story = []
    for section in enhanced_outline['sections']:
        developed_section = develop_story_section(section)
        if developed_section:
            full_story.append(developed_section)
        else:
            print(f"Failed to develop section: {section}")

    # Pair images and text
    storybook_content = []
    for section in full_story:
        paired_content = pair_image_and_text(section)
        if paired_content:
            storybook_content.append(paired_content)
        else:
            print(f"Failed to pair image and text for section: {section}")

    # Create image generation prompts
    image_prompts = []
    for content in storybook_content:
        prompt = create_image_generation_prompt(content['image_description'])
        if prompt:
            image_prompts.append(prompt)
        else:
            print(f"Failed to create image generation prompt for: {content['image_description']}")

    # Generate images
    image_urls = []
    for prompt in image_prompts:
        image_url = generate_image(prompt['prompt'])
        if image_url:
            image_urls.append(image_url)
        else:
            print(f"Failed to generate image for prompt: {prompt}")

    # Output the results
    output_results(full_story, storybook_content, image_prompts, image_urls)

# %%
# check which fabric is being used
print(subprocess.run("fabric --version", shell=True, capture_output=True, text=True))
# Out:
# CompletedProcess(args='fabric --version', returncode=127, stdout='', stderr='/bin/sh: fabric: command not found\n')
